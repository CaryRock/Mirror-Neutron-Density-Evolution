# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
vels = np.loadtxt("velocities.txt")
pdfs = np.loadtxt("pdf.txt")
cdfs = np.loadtxt("cdf.txt")
samp = np.loadtxt("sampled.txt")

# %%
plt.plot(vels, pdfs)

# %%
plt.plot(vels, cdfs)

# %%
plt.hist(samp, bins = 100); # Supress text output
